# %% [markdown]
# # Generative Kunst
#
# ## Links
#
# - [color picker](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Colors/Color_picker_tool) : Farben
# - [shoebot](https://www.nodebox.net/code/index.php/Reference) : Zeichnen
# - [numpy](http://docs.scipy.org/doc/numpy-1.10.0/reference/) : Lineare Algebra
# - [scipy](http://docs.scipy.org/doc/scipy/reference/) : Interpolation, Signalverarbeitung

# %%
import math
import numpy as np
import scipy as sp
import skimage as si
import random
from IPython.display import Image
from shoebot import bot

SEED = 1
WIDTH = 1920
HEIGHT = 1080
BACKGROUND = '#FFFFFF'

random.seed(SEED)
np.random.seed(SEED)

b = bot(outputfile="out/Template.png")
b.size(WIDTH, HEIGHT)
b.background(BACKGROUND)

# Your stuff here
# 
b.finish()
Image(filename='out/Template.png')
